# %%
import pandas as pd

# %%
file = open('InvTermfrequency.txt','r', encoding = 'utf8')

# %%
f = file.read()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20164/732222218.py in <module>
# ----> 1 f = file.read()
#
# ~\anaconda3\lib\codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xfa in position 555943: invalid start byte

# %%
print(f)

# %%
columns = []
with open("InvTermfrequency.txt", "rt") as f:
    while f.readline():
        columns.append((f.readline().split(",")[0].replace("(","").strip("'")))

# %%
columns
# Out:
# ['altatheism',
#  'altanswers',
#  'mathew',
#  'subject',
#  'atheist',
#  'summary',
#  'addresses',
#  'anything',
#  'atheism',
#  'fiction',
#  'messageid',
#  'date',
#  'mar',
#  'expires',
#  'apr',
#  'distribution',
#  'organization',
#  'consultants',
#  'uk',
#  'supersedes',
#  'archivename',
#  'december',
#  'organizations',
#  'freedom',
#  'foundation',
#  'fish',
#  'stickers',
#  'paraphernalia',
#  'us',
#  'ffrf',
#  'box',
#  'wi',
#  'evolution',
#  'sell',
#  'like',
#  'christians',
#  'cars',
#  'word',
#  'inside',
#  'moulded',
#  'postpaid',
#  'canyon',
#  'hollywood',
#  'people',
#  'francisco',
#  'area',
#  'lynn',
#  'try',
#  'figmonetcomcom',
#  'go',
#  'price',
#  'american',
#  'aap',
#  'various',
#  'bible',
#  'biblical',
#  'one',
#  'handbook',
#  'ball',
#  'foote',
#  'isbn',
#  'edition',
#  'atrocities',
#  'contains',
#  'based',
#  'james',
#  'tx',
#  'road',
#  'prometheus',
#  'haughts',
#  'horrors',
#  'east',
#  'street',
# ...

# %%
columns[0]
# Out:
# 'a'

# %%
rows = []
with open("TfIdf.txt", "rt") as f2:
    while f2.readline():
        print(f2.readline().split(',')[1])
# Out:
#  {'xref': 0.00019358230984440215
#  {'xref': 0.003760827338353928
#  {'newsgroups': 0.0
#  {'newsgroups': 0.0
#  {'path': 0.0
#  {'path': 0.0
#  {'path': 0.0
#  {'path': 0.0
#  {'path': 0.0
#  {'path': 0.0
#  {'xref': 0.0025566215403588282
#  {'path': 0.0
#  {'path': 0.0
#  {'xref': 0.004675623177412992
#  {'path': 0.0
#  {'xref': 0.003760827338353928
#  {'path': 0.0
#  {'path': 0.0
#  {'path': 0.0
#  {'newsgroups': 0.0
#  {'path': 0.0
#  {'path': 0.0
#  {'path': 0.0
#  {'newsgroups': 0.0
#  {'xref': 0.006034815961544675
#  {'xref': 0.007208252398511695
#  {'path': 0.0
#  {'path': 0.0
#  {'path': 0.0
#  {'path': 0.0
#  {'path': 0.0
#  {'path': 0.0
#  {'path': 0.0
#  {'path': 0.0
#  {'path': 0.0
#  {'newsgroups': 0.0
#  {'path': 0.0
#  {'path': 0.0
#  {'newsgroups': 0.0
#  {'newsgroups': 0.0
#  {'path': 0.0
#  {'newsgroups': 0.0
#  {'newsgroups': 0.0
#  {'path': 0.0
#  {'path': 0.0
#  {'path': 0.0
#  {'newsgroups': 0.0
#  {'newsgroups': 0.0
#  {'path': 0.0
#  {'path': 0.0
# ...

# %%
rows
# Out:
# ["('doc1'",
#  "('doc3'",
#  "('doc5'",
#  "('doc7'",
#  "('doc9'",
#  "('doc11'",
#  "('doc13'",
#  "('doc15'",
#  "('doc17'",
#  "('doc19'",
#  "('doc21'",
#  "('doc23'",
#  "('doc25'",
#  "('doc27'",
#  "('doc29'",
#  "('doc31'",
#  "('doc33'",
#  "('doc35'",
#  "('doc37'",
#  "('doc39'",
#  "('doc41'",
#  "('doc43'",
#  "('doc45'",
#  "('doc47'",
#  "('doc49'",
#  "('doc51'",
#  "('doc53'",
#  "('doc55'",
#  "('doc57'",
#  "('doc59'",
#  "('doc61'",
#  "('doc63'",
#  "('doc65'",
#  "('doc67'",
#  "('doc69'",
#  "('doc71'",
#  "('doc73'",
#  "('doc75'",
#  "('doc77'",
#  "('doc79'",
#  "('doc81'",
#  "('doc83'",
#  "('doc85'",
#  "('doc87'",
#  "('doc89'",
#  "('doc91'",
#  "('doc93'",
#  "('doc95'",
#  "('doc97'",
#  "('doc99'",
#  "('doc101'",
#  "('doc103'",
#  "('doc105'",
#  "('doc107'",
#  "('doc109'",
#  "('doc111'",
#  "('doc113'",
#  "('doc115'",
#  "('doc117'",
#  "('doc119'",
#  "('doc121'",
#  "('doc123'",
#  "('doc125'",
#  "('doc127'",
#  "('doc129'",
# ...
